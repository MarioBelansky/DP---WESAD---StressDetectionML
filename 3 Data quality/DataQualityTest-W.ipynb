# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("WESAD_All_W.csv")

# %%
data
# Out:
#              ACC_0        ACC_1        ACC_2        BVP          EDA  \
# 0       126.326243 -1012.375512  1296.163595  13.570802  5452.450365
# 1        55.142882  -635.294579   753.130788  23.360416  5366.846848
# 2        90.734562  -669.574663   636.766616  41.930454  5264.122627
# 3       161.917923  -395.333985   675.554673 -17.274044  5115.746165
# 4        90.734562  -669.574663   636.766616  41.930454  5264.122627
# ...            ...          ...          ...        ...          ...
# 315059   57.652528   918.940551   887.251551 -21.989961 -1141.515991
# 315060   57.652528   918.940551   887.251551   6.970496 -1141.515991
# 315061   57.652528   918.940551   887.251551 -21.989961 -1141.515991
# 315062   57.652528   918.940551   887.251551  11.107704 -1136.589079
# 315063   57.652528   918.940551   887.251551   9.184598 -1151.365964
#
#                 TEMP  labels  id
# 0       10279.722091     0.0   2
# 1       10279.722091     0.0   2
# 2       10279.722091     0.0   2
# 3       10279.722091     0.0   2
# 4       10279.722091     0.0   2
# ...              ...     ...  ..
# 315059 -11412.917628     0.0  17
# 315060 -11802.683112     0.0  17
# 315061 -11412.917628     0.0  17
# 315062 -11412.917628     0.0  17
# 315063 -11412.917628     0.0  17
#
# [315064 rows x 8 columns]

# %%
print("Základné infromácie")
print(data.info())
# Out:
# Základné infromácie
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315064 entries, 0 to 315063
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ACC_0   315064 non-null  float64
#  1   ACC_1   315064 non-null  float64
#  2   ACC_2   315064 non-null  float64
#  3   BVP     315064 non-null  float64
#  4   EDA     315064 non-null  float64
#  5   TEMP    315064 non-null  float64
#  6   labels  315064 non-null  float64
#  7   id      315064 non-null  int64
# dtypes: float64(7), int64(1)
# memory usage: 19.2 MB
# None

# %%
print("\nštatistika:")
print(data.describe())
# Out:
# štatistika:
#                ACC_0          ACC_1          ACC_2            BVP  \
# count  315064.000000  315064.000000  315064.000000  315064.000000
# mean        0.072709      -0.016919       0.155563       0.085063
# std       359.861991    1068.015303     771.919627      57.637404
# min     -2587.838223   -5404.725681   -4247.652323    -922.963495
# 25%      -164.605470    -493.310433    -387.135089     -14.297718
# 50%        14.758692     -10.461047      25.345141       2.456343
# 75%       182.336988     624.499405     406.593982      16.434397
# max      2763.934651    5214.209208    5684.812168    1040.860597
#
#                 EDA          TEMP         labels             id
# count  3.150640e+05  3.150640e+05  315064.000000  315064.000000
# mean  -1.474886e-11  2.621764e-09       0.177135       9.262432
# std    1.038734e+04  1.329100e+04       0.381784       4.637376
# min   -3.333524e+04 -6.622064e+04       0.000000       2.000000
# 25%   -3.510111e+03 -6.151084e+03       0.000000       5.000000
# 50%   -1.167495e+03  1.251072e+03       0.000000       9.000000
# 75%    8.584580e+02  7.486156e+03       0.000000      14.000000
# max    6.557577e+04  3.627050e+04       1.000000      17.000000

# %%
print("\nTest na chýbajúce hodnoty:")
print(data.isnull().sum())
# Out:
# Test na chýbajúce hodnoty:
# ACC_0     0
# ACC_1     0
# ACC_2     0
# BVP       0
# EDA       0
# TEMP      0
# labels    0
# id        0
# dtype: int64

# %%
duplicate_rows = data.duplicated()
print("\nDuplikátne hodnoty:", duplicate_rows.sum())
# Out:
# Duplikátne hodnoty: 157408

# %%
print("\nVizualizácia rozdelenia:")
data.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()
# Out:
# Vizualizácia rozdelenia:

# %%
print("\nOutliers:")
data.boxplot(figsize=(10, 6))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Outliers:

# %%
print("\nKorelácia:")
correlation_matrix = data.corr()
plt.figure(figsize=(8, 6))
plt.matshow(correlation_matrix, cmap='coolwarm', fignum=1)
plt.colorbar()
plt.xticks(range(len(data.columns)), data.columns, rotation=90)
plt.yticks(range(len(data.columns)), data.columns)
plt.show()
# Out:
# Korelácia:
