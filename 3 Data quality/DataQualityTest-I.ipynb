# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("WESAD_All_I.csv")

# %%
data
# Out:
#               ACC_0        ACC_1        ACC_2        BVP          EDA  \
# 0        126.326243 -1012.375512  1296.163595  13.570802  5452.450365
# 1        179.713763  -875.255173   966.465105  13.144006  5447.100145
# 2        233.101284  -738.134833   636.766616  13.032862  5441.749925
# 3        322.080484  -738.134833   830.706904  12.975067  5436.399706
# 4        411.059685  -738.134833  1024.647192  12.855030  5431.049486
# ...             ...          ...          ...        ...          ...
# 5041019   57.652528   918.940551   887.251551  -1.379833 -1151.365964
# 5041020   57.652528   918.940551   887.251551  -2.860118 -1151.365964
# 5041021   57.652528   918.940551   887.251551  -4.340404 -1151.365964
# 5041022   57.652528   918.940551   887.251551  -5.833341 -1151.365964
# 5041023   57.652528   918.940551   887.251551  -7.402191 -1151.365964
#
#                  TEMP  labels  id
# 0        10279.722091     0.0   2
# 1        10279.722091     0.0   2
# 2        10279.722091     0.0   2
# 3        10279.722091     0.0   2
# 4        10279.722091     0.0   2
# ...               ...     ...  ..
# 5041019 -11412.917628     0.0  17
# 5041020 -11412.917628     0.0  17
# 5041021 -11412.917628     0.0  17
# 5041022 -11412.917628     0.0  17
# 5041023 -11412.917628     0.0  17
#
# [5041024 rows x 8 columns]

# %%
print("Základné infromácie")
print(data.info())
# Out:
# Základné infromácie
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5041024 entries, 0 to 5041023
# Data columns (total 8 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   ACC_0   float64
#  1   ACC_1   float64
#  2   ACC_2   float64
#  3   BVP     float64
#  4   EDA     float64
#  5   TEMP    float64
#  6   labels  float64
#  7   id      int64
# dtypes: float64(7), int64(1)
# memory usage: 307.7 MB
# None

# %%
print("\nštatistika:")
print(data.describe())
# Out:
# štatistika:
#               ACC_0         ACC_1         ACC_2           BVP           EDA  \
# count  5.041024e+06  5.041024e+06  5.041024e+06  5.041024e+06  5.041024e+06
# mean  -6.811485e-06  1.915599e-04 -4.055843e-05  6.670979e-17 -9.825111e-03
# std    3.592474e+02  1.067910e+03  7.712800e+02  5.780071e+01  1.038669e+04
# min   -2.587838e+03 -6.712855e+03 -4.635639e+03 -1.395831e+03 -3.333524e+04
# 25%   -1.646146e+02 -4.933104e+02 -3.871351e+02 -1.439168e+01 -3.508458e+03
# 50%    1.475869e+01 -1.180168e+01  2.534514e+01  2.464602e+00 -1.166829e+03
# 75%    1.823370e+02  6.244994e+02  4.065940e+02  1.642749e+01  8.576526e+02
# max    3.237768e+03  6.368441e+03  5.995202e+03  1.457104e+03  6.557577e+04
#
#                TEMP        labels            id
# count  5.041024e+06  5.041024e+06  5.041024e+06
# mean  -3.227415e-02  1.771372e-01  9.262445e+00
# std    1.329047e+04  3.817848e-01  4.637366e+00
# min   -6.622064e+04  0.000000e+00  2.000000e+00
# 25%   -6.151084e+03  0.000000e+00  5.000000e+00
# 50%    1.251072e+03  0.000000e+00  9.000000e+00
# 75%    7.486156e+03  0.000000e+00  1.400000e+01
# max    3.627050e+04  1.000000e+00  1.700000e+01

# %%
print("\nTest na chýbajúce hodnoty:")
print(data.isnull().sum())
# Out:
# Test na chýbajúce hodnoty:
# ACC_0     0
# ACC_1     0
# ACC_2     0
# BVP       0
# EDA       0
# TEMP      0
# labels    0
# id        0
# dtype: int64

# %%
duplicate_rows = data.duplicated()
print("\nDuplikátne hodnoty:", duplicate_rows.sum())
# Out:
# Duplikátne hodnoty: 1501395

# %%
print("\nVizualizácia rozdelenia:")
data.hist(figsize=(10, 10))
plt.tight_layout()
plt.show()
# Out:
# Vizualizácia rozdelenia:

# %%
print("\nOutliers:")
data.boxplot(figsize=(10, 6))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Outliers:

# %%
print("\nKorelácia:")
correlation_matrix = data.corr()
plt.figure(figsize=(8, 6))
plt.matshow(correlation_matrix, cmap='coolwarm', fignum=1)
plt.colorbar()
plt.xticks(range(len(data.columns)), data.columns, rotation=90)
plt.yticks(range(len(data.columns)), data.columns)
plt.show()
# Out:
# Korelácia:
